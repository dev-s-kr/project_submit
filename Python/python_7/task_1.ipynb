# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter33 ~ 41 수업은 잘 들으셨나요?
#
# Chapter33 ~ 41의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 사용자로부터 두 개의 숫자를 입력받아 나눗셈을 수행하는 프로그램을 작성하세요.
#
# [예외처리]
# - 입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
# - 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
# - 위 2가지 예외처리 후 사용자에게 이해하기 쉬운 메시지 작성 후 출력되도록 코드를 작성

# %%
try:
    num1, num2 = map(int, input("나눌 두 수를 입력하세요.(공백으로 구분합니다.) : ").split(" "))
    print(num1 / num2)
except ValueError:
    print("입력값이 숫자가 아닙니다.")
except ZeroDivisionError:
    print("0으로 나눌 수 없습니다.")
# Out:
# 나눌 두 수를 입력하세요.(공백으로 구분합니다.) : 0 1
# 0.0

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 파일을 읽어서 내용을 출력하는 프로그램을 작성하세요.
#
# - 파일이 존재하지 않을 때 발생하는 FileNotFoundError를 처리
# - 파일이 존재하지 않을 경우 "파일을 찾을 수 없습니다."라는 메시지를 출력

# %%
try:
    with open("test.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("파일을 찾을 수 없습니다.")
# Out:
# 파일을 찾을 수 없습니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
numbers = []

while True:
    try:
        user_input = input("추가할 숫자를 입력하세요. 그만 입력하려면 [done]을 입력하세요. : ")
        print("-" * 50)
        if user_input == "done":
            break
        numbers.append(int(user_input))
        print("추가한 숫자 :", numbers)
        print("-" * 50)
    except ValueError:
        print(f"잘못된 값 : {user_input}. 숫자를 입력해주세요.")
        print("-" * 50)
print("결과 :", numbers)
# Out:
# 추가할 숫자를 입력하세요. 그만 입력하려면 [done]을 입력하세요. : 1
# --------------------------------------------------
# 추가한 숫자 : [1]
# --------------------------------------------------
# 추가할 숫자를 입력하세요. 그만 입력하려면 [done]을 입력하세요. : 2
# --------------------------------------------------
# 추가한 숫자 : [1, 2]
# --------------------------------------------------
# 추가할 숫자를 입력하세요. 그만 입력하려면 [done]을 입력하세요. : 3
# --------------------------------------------------
# 추가한 숫자 : [1, 2, 3]
# --------------------------------------------------
# 추가할 숫자를 입력하세요. 그만 입력하려면 [done]을 입력하세요. : a
# --------------------------------------------------
# 잘못된 값 : a. 숫자를 입력해주세요.
# --------------------------------------------------
# 추가할 숫자를 입력하세요. 그만 입력하려면 [done]을 입력하세요. : done
# --------------------------------------------------
# 결과 : [1, 2, 3]

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 사용자 정의 예외 NegativeNumberError를 생성하고, 사용자로부터 숫자를 입력받아 음수일 경우 NegativeNumberError를 발생시키는 프로그램을 작성하세요.
#
# - 예외 처리 구문을 사용하여 음수 입력 시 "양수를 입력해주세요."라는 메시지를 출력

# %%
class NegativeNumberError(Exception):
    pass

try:
    num = int(input("정수를 입력해주세요. : "))
    if num < 0:
        raise NegativeNumberError
    print("결과 :", num)
except NegativeNumberError:
    print("예외 : 양수를 입력해주세요.")
# Out:
# 정수를 입력해주세요. : -1
# 예외 : 양수를 입력해주세요.

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
import datetime

now = datetime.datetime.now()
now_format = f"{now.year}년 {now.month}월 {now.day}일 {now.hour}시 {now.minute}분 {now.second}초"
print(now_format)

user_year = int(input("태어난 연도를 입력해주세요. : "))
user_age = now.year - user_year + 1
print("나이 :", user_age)
# Out:
# 2025년 6월 9일 5시 6분 18초
# 태어난 연도를 입력해주세요. : 2021
# 나이 : 5

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# requests 모듈을 사용하여, 웹 페이지의 HTML을 가져오는 간단한 웹 스크레이퍼를 작성하세요.
#
# 'https://kream.co.kr/'에서<br>
# 데이터를 가져와서 상태 코드와 HTML의 첫 100자를 출력하세요.<br>
# (실습 전 requests 모듈을 설치해야 함)

# %%
import requests

target = requests.get("https://kream.co.kr/")
print("상태 코드 :", target.status_code)
print("-" * 50)
print("HTML의 첫 100자 :", target.text[:100])
# Out:
# 상태 코드 : 500
# --------------------------------------------------
# HTML의 첫 100자 : <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta name="robots" content="noindex, nofollow" />
# <meta htt

# %% [markdown]
# ---

# %% [markdown]
# [문제 7]
#
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %%
import time

def timer_decorator(function):
    def wrapper():
        start_time = time.time()
        result = function()
        end_time = time.time()
        print(f"함수 실행 시간 : {end_time - start_time:.2f}초")
    return wrapper

@timer_decorator
def test():
    for i in range(100000000):
        pass

test()
# Out:
# 함수 실행 시간 : 2.68초

# %% [markdown]
# ---

# %% [markdown]
# [문제 8]
#
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
#mymath.py

def triangle_area(base, height):
    return base * height / 2
def circle_area(radius):
    return radius * 3.14 ** 2
def rectangular_prism_area(length, width, height):
    return length * width * height

# %%
import mymath

result1 = triangle_area(3, 4)
result2 = circle_area(5)
result3 = rectangular_prism_area(3, 4, 5)

print(result1)
print(result2)
print(result3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-60-a6f9b3fa4eb7> in <cell line: 0>()
# ----> 1 import mymath
#       2
#       3 result1 = triangle_area(3, 4)
#       4 result2 = circle_area(5)
#       5 result3 = rectangular_prism_area(3, 4, 5)
#
# ModuleNotFoundError: No module named 'mymath'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# [문제 9]
#
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %%
#mammals.py

class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        return f"이름 : {self.name}, 나이 : {self.age}"

# %%
#birds.py

class Eagle:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        return f"이름 : {self.name}, 나이 : {self.age}"

# %%
import mammals
import birds

dog = mammals.Dog("초코", 2)
eagle = birds.Eagle("하늘이", 1)

print(dog.info())
print(eagle.info())

# %% [markdown]
# ---
